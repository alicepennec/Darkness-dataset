# %%
import pandas as pd

# %%
df = pd.read_csv('darkness-dataset.csv', delimiter=';')

# %%
df.head()
# Out:
#   id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id  \
# 0  random-id-2468,"Random Name","KW","","Kuwait",...
# 1  random-id-1357,"Random Name","IN","Random EduT...
# 2  random-id-8642,"Random Name","","","","{""comp...
# 3  random-id-9512,"Random Name","UK","Design Engi...
# 4  random-id-8642,"Random Name","KW","","Kuwait",...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
# Supprimer les guillemets de la colonne
df[0] = df[0].str.replace('"', '', regex=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Raux Familly\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 2
# ...

# %%
df.head()
# Out:
#   id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id  \
# 0  random-id-2468,"Random Name","KW","","Kuwait",...
# 1  random-id-1357,"Random Name","IN","Random EduT...
# 2  random-id-8642,"Random Name","","","","{""comp...
# 3  random-id-9512,"Random Name","UK","Design Engi...
# 4  random-id-8642,"Random Name","KW","","Kuwait",...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
split_columns = df['id'].str.split(',', expand=True)

# Vérifiez le nombre de colonnes
print(split_columns.shape[1])  # Affiche le nombre de colonnes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Raux Familly\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ...

# %%
print(df.iloc[:, 0].head())
# Out:
# 0    random-id-2468,"Random Name","KW","","Kuwait",...
# 1    random-id-1357,"Random Name","IN","Random EduT...
# 2    random-id-8642,"Random Name","","","","{""comp...
# 3    random-id-9512,"Random Name","UK","Design Engi...
# 4    random-id-8642,"Random Name","KW","","Kuwait",...
# Name: id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id, dtype: object

# %%
df_to_clean = df.iloc[:,0].str.split(',',expand=True)
df_to_clean
# Out:
#                     0              1     2    \
# 0        random-id-2468  "Random Name"  "KW"
# 1        random-id-1357  "Random Name"  "IN"
# 2        random-id-8642  "Random Name"    ""
# 3        random-id-9512  "Random Name"  "UK"
# 4        random-id-8642  "Random Name"  "KW"
# 5        random-id-7531  "Random Name"  "KW"
# 6        random-id-7890  "Random Name"  "DZ"
# 7        random-id-4820  "Random Name"  "NG"
# 8        random-id-9025  "Random Name"  "UK"
# 9        random-id-5837  "Random Name"  "EG"
# 10       random-id-5847  "Random Name"  "GB"
# 11  random-id-12286a197  "Random Name"  "EG"
#
#                                                   3    \
# 0                                                  ""
# 1                                    "Random EduTech"
# 2                                                  ""
# 3   "Design Engineer (System health) at Random Pow...
# 4                                                  ""
# ...

# %%
data=df.iloc[:,0].str.split(r',(?=(?:[^{}]*\{[^{}]*\})*[^{}]*$)',expand=True)
data
# Out:
#                                                    0   \
# 0                                      random-id-2468
# 1                                      random-id-1357
# 2                                      random-id-8642
# 3   random-id-9512,"Random Name","UK","Design Engi...
# 4                                      random-id-8642
# 5                                      random-id-7531
# 6                                      random-id-7890
# 7                                      random-id-4820
# 8                                      random-id-9025
# 9                                      random-id-5837
# 10  random-id-5847,"Random Name","GB","Community A...
# 11                                random-id-12286a197
#
#                                                    1   \
# 0                                       "Random Name"
# 1                                       "Random Name"
# 2                                       "Random Name"
# ...

# %%
data.shape
# Out:
# (9, 59)

# %%
# Créer une nouvelle liste de colonnes pour le deuxième DataFrame
new_columns = [
    'id', 'name', 'country_code', 'position', 'city', 
    'current_company', 'about', 'posts', 'experience', 'url',
    'followers', 'connections', 'current_company_company_id',
    'current_company_name', 'publications', 'patents', 
    'projects', 'organizations', 'input_url', 'linkedin_id'
]

# %%
# Créer le nouveau DataFrame avec les colonnes souhaitées
df_clean = pd.DataFrame(columns=new_columns)
print(df_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          0 non-null      object
#  1   name                        0 non-null      object
#  2   country_code                0 non-null      object
#  3   position                    0 non-null      object
#  4   city                        0 non-null      object
#  5   current_company             0 non-null      object
#  6   about                       0 non-null      object
#  7   posts                       0 non-null      object
#  8   experience                  0 non-null      object
#  9   url                         0 non-null      object
#  10  followers                   0 non-null      object
#  11  connections                 0 non-null      object
#  12  current_company_company_id  0 non-null      object
# ...

# %%
df_to_clean[0] = df_to_clean[0].str.extract(r'-(\d+)$')  # Capture tout après le dernier tiret

# Vérifiez le DataFrame
print(df_to_clean[[0]].head())
# Out:
#       0
# 0  2468
# 1  1357
# 2  8642
# 3  9512
# 4  8642

# %%
df_to_clean.shape
# Out:
# (12, 115)

# %%
df_clean['id'] = df_to_clean[0].to_list()

# %%
df_clean
# Out:
#      id name country_code position city current_company about posts  \
# 0  2468  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 1  1357  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 2  8642  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 3  9512  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 4  8642  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 5  7531  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 6  4820  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 7  9025  NaN          NaN      NaN  NaN             NaN   NaN   NaN
# 8  5837  NaN          NaN      NaN  NaN             NaN   NaN   NaN
#
#   experience  url followers connections current_company_company_id  \
# 0        NaN  NaN       NaN         NaN                        NaN
# 1        NaN  NaN       NaN         NaN                        NaN
# 2        NaN  NaN       NaN         NaN                        NaN
# ...

# %%
df_clean['country_code'] = df_to_clean[2].to_list()
df_clean['city'] = df_to_clean[4].to_list()

# %%
df_clean
# Out:
#       id name country_code position                      city current_company  \
# 0   2468  NaN         "KW"      NaN                  "Kuwait"             NaN
# 1   1357  NaN         "IN"      NaN                    "Noida             NaN
# 2   8642  NaN           ""      NaN                        ""             NaN
# 3   9512  NaN         "UK"      NaN              "Galashiels"             NaN
# 4   8642  NaN         "KW"      NaN                  "Kuwait"             NaN
# 5   7531  NaN         "KW"      NaN                  "Kuwait"             NaN
# 6   7890  NaN         "DZ"      NaN                   "Biskra             NaN
# 7   4820  NaN         "NG"      NaN                 "Nigeria"             NaN
# 8   9025  NaN         "UK"      NaN                        ""             NaN
# 9   5837  NaN         "EG"      NaN                   "Cairo"             NaN
# 10  5847  NaN         "GB"      NaN  "Greater Cambridge Area"             NaN
# ...
